# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns
# import plotly.express as px
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1396/1086932276.py in <module>
#       2 import pandas as pd
#       3 import seaborn as sns
# ----> 4 import plotly.express as px
#
# ModuleNotFoundError: No module named 'plotly'

# %% [markdown]
# # Create the youtube service

# %%
api_key = 'AIzaSyCT_3-NhxiEmMJrZA96sNL8PzGzrpUpPcg'
channel_ids = ['UCbXgNpp0jedKWcQiULLbDTA', #PythonEngineer
               'UCmXmlB4-HJytD7wek0Uo97A', #JSMastery
               'UClb90NQQcskPUGDIXsQEz5Q', #Dev Ed
               'UC-8QAzbLcRglXeN_MY9blyw', #Ben Awad
               'UCaO6VoaYJv4kS-TQO_M-N_g', #Clement
              ]

youtube = build('youtube','v3', developerKey=api_key)

# %% [markdown]
# # Function to get channel statistics

# %%
def get_channel_stats(youtube, channel_ids):
    
    all_data = []
    request = youtube.channels().list(
        part='snippet,contentDetails,statistics',
        id= ','.join(channel_ids))
    response = request.execute()
    
    for i in range(len(response['items'])):
        data = dict(Channel_name = response['items'][i]['snippet']['title'],
                    Subscribers = response['items'][i]['statistics']['subscriberCount'],
                    Views = response['items'][i]['statistics']['viewCount'],
                    Total_videos = response['items'][i]['statistics']['videoCount'],
                    playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    return all_data

# %%
channel_statistics = get_channel_stats(youtube, channel_ids)

# %%
channel_data = pd.DataFrame(channel_statistics)

# %%
channel_data
# Out:
#          Channel_name Subscribers     Views Total_videos  \
# 0     Python Engineer       79800   3933769          154
# 1            Ben Awad      374000  33941032         1096
# 2              Dev Ed      716000  38824708          217
# 3  Clément Mihailescu      401000  49084218          212
# 4  JavaScript Mastery      199000   8032866           65
#
#                 playlist_id
# 0  UUbXgNpp0jedKWcQiULLbDTA
# 1  UU-8QAzbLcRglXeN_MY9blyw
# 2  UUlb90NQQcskPUGDIXsQEz5Q
# 3  UUaO6VoaYJv4kS-TQO_M-N_g
# 4  UUmXmlB4-HJytD7wek0Uo97A

# %%
channel_data['Subscribers'] = pd.to_numeric(channel_data['Subscribers'])
channel_data['Views'] = pd.to_numeric(channel_data['Views'])
channel_data['Total_videos'] = pd.to_numeric(channel_data['Total_videos'])

# %%
channel_data.dtypes
channel_data.to_csv('Channel_Details.csv')

# %%
sns.set(rc={'figure.figsize':(10,8)})
ax = sns.barplot(x='Channel_name',y='Subscribers', data=channel_data)

# %%
ax = sns.barplot(x='Channel_name',y='Views', data=channel_data)

# %%
ax = sns.barplot(x='Channel_name',y='Total_videos', data=channel_data)

# %% [markdown]
# ## Function to get video ids

# %%
playlist_id = channel_data.loc[channel_data['Channel_name']=='Ben Awad', 'playlist_id'].iloc[0]

# %%
playlist_id
# Out:
# 'UU-8QAzbLcRglXeN_MY9blyw'

# %%
def get_video_ids(youtube, playlist_id):
    
    request = youtube.playlistItems().list(
              part='contentDetails',
              playlistId=playlist_id,
              maxResults = 50)
    response = request.execute()
    
    video_ids = []
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                      part='contentDetails',
                      playlistId=playlist_id,
                      maxResults = 50,
                      pageToken = next_page_token)
            response = request.execute()
            
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
            next_page_token = response.get('nextPageToken')
            
    return video_ids

# %%
video_ids = get_video_ids(youtube, playlist_id)

# %%
video_ids
# Out:
# ['IVNvTJ2-_Hk',
#  'v9jSFtD40Wk',
#  'LY4rxYe-jKI',
#  'XEt09iK8IXs',
#  'UX0Lf4gBW8s',
#  '0Tm1GDeBxus',
#  'FU7HBr2d9HM',
#  '9XDhuprRPZ8',
#  'ViYUp7jsJNM',
#  '6HvcW6eX3HE',
#  '7FQls0Grqbc',
#  'h7U_lcg0QlQ',
#  'HaxJSvZ6wzA',
#  '6s0OVdoo4Q4',
#  '8-ZdZ7vswn0',
#  'YIL5fuAUPiA',
#  'I8PkQgPiSq8',
#  'IKc_RH33-uM',
#  'AACGbCOqSmo',
#  'EoebziXTglk',
#  'bngsrbFI2UY',
#  'Dk1gxZ_K3E0',
#  'FmAL5qvJkaI',
#  'yjTVMXammAw',
#  'ZLH1_C-UNHw',
#  'oa84RnBsieo',
#  '1PBNAoKd-70',
#  'Fc9pWYP1f6o',
#  '8YJqB4pNNgs',
#  'hy-EhJ_tTQo',
#  'pSUdOmrd2Wg',
#  'ijL0h6-1qbQ',
#  'pXDM5CA47Mg',
#  'pNb6qSV6z7A',
#  'c4jB2AYJWl0',
#  'a5DX5pQ9p5M',
#  'thqX845NEgg',
#  'bfd8RyAJh6c',
#  'gnkrDse9QKc',
#  'CHO316LKnZw',
#  'ApR-kNXxLUs',
#  'E5xThvyaGbE',
#  'AuMeockiuLs',
#  'gQkwzVnXyh4',
#  'RxkLFAGetVQ',
#  'xgER1OutVvU',
#  '4jkSiIBDDZ8',
#  'PJ0QSJpJn2U',
#  'KfU2mPwVE8E',
#  '3OhLUYNw0TI',
#  '_B7pGf8QJWo',
#  '6i-cagHpBcs',
#  'bAB_nNf8-a0',
#  'mZWsyUKwTbg',
#  'I6ypD7qv3Z8',
#  'elBpRf9PX0Q',
#  'BhQYZmaxTCM',
#  'Yg3C38P5EkA',
#  '_Q6TTdIEAvQ',
#  'Ap1CzrIBIVw',
#  'wO5hFk2QsD8',
#  '2ndv5-3CIrs',
#  'MT6M_sqAuZo',
#  'gc8mDZwUlfo',
#  'fhr3yxYf-P0',
#  'xTsYYxf2Ut0',
#  'Hfr-e13av5I',
#  'CQaDl9Fu0W0',
#  'NH5JzwgAcUw',
#  'bZjGSNPCXdU',
#  'P6cInhvnX9E',
#  'QGlCjVG-Hyc',
#  'crYNfZs24yc',
#  'tw1E9vVYWa8',
#  'bx3--22D4E4',
#  'Ptrhz2zW--o',
#  'QVkPCb7MduY',
#  'CYlUcIH3dPg',
#  'pY0vWYLDDco',
#  'FCIATrUJrdU',
#  '_W-tcVzu-Ms',
#  '2AVs-Yh1bS8',
#  'f9TAKPU8-g8',
#  'Hln37dE19bs',
#  'TfGvBc8UnZ8',
#  'rGYbrIf-y58',
#  'ptTfQvbu9Ko',
#  'bPae4Z8BFt8',
#  'enLUX1TtNyE',
#  'N2q-ZYuQWI8',
#  '5rUNlYs6wu4',
#  'tp_5c6jaNQE',
#  'JbV7MCeEPb8',
#  'uFH5S5dUPr8',
#  'Rz1woD9L45Q',
#  'UOxTMOCTEZk',
#  'O0sywQnY8sM',
#  'uCbFMZYQbxE',
#  '1BPQj438FyQ',
#  'bm4pO6baNLc',
#  'Kx_1NYYJS7Q',
#  'OVdPOExxKuU',
#  'WhzIjYQmWvs',
#  'DvVt11mPuM0',
#  'gnupOrSEikQ',
#  'FD50LPJ6bjE',
#  'QHfPbnbvyeE',
#  'ZNbosPOEEWw',
#  'KO8rPRyCZd4',
#  '8WnGNId62h8',
#  'Z78qvpyejQc',
#  'fTFoBr5LJGE',
#  'VnG7ej56lWw',
#  '-A3n5N8XwpQ',
#  'O8d_42Wc-po',
#  'yAUuZXcCwcw',
#  'ya1fwxnmlQs',
#  'Hh_kiZTTBr0',
#  'ZAsZ2hhdj-s',
#  'JJSloXLTyNg',
#  'RVNC61rkFxw',
#  'M6N7gEZ-IUQ',
#  '25GS0MLT8JU',
#  'iD49_NIQ-R4',
#  'YkcNFNLtSfQ',
#  'Z5iWr6Srsj8',
#  '0N3n56KsC28',
#  '110dW3l5GQY',
#  'nViEqpgwxHE',
#  'AYZOHt6kz6Y',
#  'DiBQZpb_al0',
#  'uw4lh4zsTs0',
#  'D6or2gdrHRE',
#  'IiwGbcd8S7I',
#  'R2pBWDnfJY8',
#  '4WTV6ZCY4qo',
#  'uHjPTUpQOAk',
#  'bRAcWk9S-6g',
#  '6CMmL9iF_bA',
#  '1FGDM3MrF64',
#  'qeKP2A7bLUw',
#  'R0QMjpCPHOg',
#  'KnQ6xcVgJec',
#  '0n_s1PLb_uY',
#  'huLpYZ207pc',
#  'tsM3N_7bNcE',
#  'fuzPXzkfebo',
#  'f687hBjwFcM',
#  'Mofujsl94Vc',
#  '_AYuhmz-fX4',
#  'lhMKvyLRWo0',
#  'wcRawY6aJaw',
#  'RkBg0gDTLU8',
#  '-Ls48dd-vJE',
#  'ommC6fS1SZg',
#  'W6AJ-gRupCs',
#  'j1ZRyw7OtZs',
#  '9xhKH43llhU',
#  '1UcLoOD1lRM',
#  'nfNrfi7HmLs',
#  '_trOqBZMJHQ',
#  'fWD_ciSWklQ',
#  '00RoZflFE34',
#  'ejWS2g0Td08',
#  'is83bEK3n5A',
#  'VjmAzW2lrR8',
#  'CXmocTjl3ko',
#  'zKErPUbiFLk',
#  'NllFeGH6QZ0',
#  'dr9I4xPYkdw',
#  'HZo4KElzEh4',
#  'D_W24XkXHSw',
#  'Nws67CnAGVc',
#  'NnwkRvElx9E',
#  'j7LAhP608RU',
#  'Ufwbp838yZA',
#  '0xjfkl9nODQ',
#  'jsaOTcBe-dM',
#  'EIolal0VsoE',
#  'G0r0JOocfL4',
#  'lsmsaQXOzTw',
#  '9HFwJ9hrmls',
#  'ThN_1Kgald8',
#  'CmuUQymjbRo',
#  'pGSzMfKBV9Q',
#  '-Zx-9BKgTAs',
#  '5gUHfe-ETuo',
#  'o-alRbk_zP0',
#  'mg_pDqszL3g',
#  'eTDnfS2_WE4',
#  'rtQKP1we-Dk',
#  'lEF_MazpWJo',
#  'OEqkFl1-G7Y',
#  '06pWsB_hoD4',
#  '4tk0Ak-dEjs',
#  'ao4C9dJO7n0',
#  '-quoT1xVje0',
#  'RKh5y4ZfnIY',
#  'XpR7p71PE0I',
#  '3Pxj-4IrOcs',
#  'KkkdwK1VbLc',
#  'RUZB8tpyDbQ',
#  'zbp8LZXBUYc',
#  'LZwlTQ6dHHs',
#  'kpO3knzcoFM',
#  'wBrSXBpAd10',
#  'Rrja1F-W8t8',
#  'fTP2gi7e3k8',
#  'k5cwVCvEhFM',
#  '7Lt1l3YGqYg',
#  'RI9kA09Egas',
#  'dgg1dvs0Bn4',
#  '4sZJASynNcY',
#  'uHlAM4ICi1s',
#  'EuaVr7vFF5E',
#  'pNjeuU4Jwnc',
#  '6VmVYi9yrAA',
#  'Vwk9LeyB1Ic',
#  'eHn64NxMwJY',
#  '1ieedETExwc',
#  'YFkJGEefgU8',
#  '7Uxm5YvXmpE',
#  '_voliLLuIbE',
#  'wKd8hP4Gse0',
#  '3oXmDUH1u8Y',
#  'glsK0PBMjJs',
#  'DlgEF077sP4',
#  'Dm0TXbGvgvo',
#  '3GtAE9RZHVc',
#  '1OX-mns8UJw',
#  't50ecup_0Nw',
#  '5mAnn2u9KRM',
#  'oAtazW3rIUg',
#  'GHNt5Drsaxs',
#  'E622pyzvQP8',
#  'e4t5gbmVfHo',
#  '9dRk3bxEbS8',
#  'lQ7t20gFR14',
#  'HnKaaDcWOXw',
#  'bC08Qb1mSXo',
#  '5YYsfkl2UCM',
#  'yVMhwieccD0',
#  'UwewEk-9nWk',
#  'hLcAlln-D_s',
#  'NrURtp0fecg',
#  'YAHZLEsEB5w',
#  'gifcm4UC3Ko',
#  'mL8MorfajQc',
#  'nKA1Tg02CuY',
#  '_63IA-Ly0gY',
#  'kanCgiBCbhU',
#  'slGMKIDg7gM',
#  'o5PQEGTPOeo',
#  'mjCBeQDgOtk',
#  'szfUbzsKvtE',
#  'iAFY-21UGvE',
#  '20PG7aehR1M',
#  't9kSTiqhUfg',
#  'EwU1Hl-tV50',
#  'CnhHeSAAbRM',
#  'camfkdmuR8M',
#  'zprUqiLzHtc',
#  'W796zjFVHSI',
#  'JkI_Ds9axxY',
#  's7z5reu03RQ',
#  'iEBCzzMWV_A',
#  'N5UU_Np2MJI',
#  'o2ReDO0crHQ',
#  'wfelgwEThME',
#  'vmf9-8mHYHM',
#  'HV707MgiOCg',
#  '4vJjZcLh0fc',
#  'oQiMXRsO4o4',
#  'k8rc9hdJ0Lc',
#  'm5sf3LNhvc0',
#  'N2q8Hlxdpx0',
#  'J0b11tvEkFQ',
#  'sfO2IpclTBA',
#  '8eFgz06QPMs',
#  '9rnQ-MLjK9s',
#  'mfB_j2rEFRI',
#  'S1pxdAL2Dz8',
#  'E-j-vlDuYtA',
#  'M4rYfq5foPA',
#  'VoscwJ6MGsU',
#  'h7nYxVjVPSk',
#  'B8rOrLt3-9s',
#  'xxr2htAXgN4',
#  'dvMByjOanbk',
#  'dX84cb1mxVw',
#  'jmsv7OVb20U',
#  'a6mhEFHDdCk',
#  'dT7E9CGuXbk',
#  'izriJQeqGUA',
#  'U86hn1HmuFU',
#  'kfmh2mMf3fs',
#  'ksjvZMYGgqI',
#  '8kZ7W-bI5qQ',
#  'FIklsrdUojA',
#  'svCTgx6abFc',
#  'p6qoJ4apCjA',
#  'udbamzg8z6s',
#  'mgxNeYjHbsI',
#  's35EmAn9Zl8',
#  'fYBlg9oOvQM',
#  'zR8jKR9hnFA',
#  'fxYcbw56mbk',
#  'j9dOdjBzARo',
#  'Jksj60x1TsI',
#  'OP39UioapL8',
#  '3t3tmfDwWB4',
#  '3Vi_ztI0BeA',
#  'JSo5FtG4Xvk',
#  'bqdEXPzjzQ4',
#  '8yZImm2A1KE',
#  'ZnuhX2zgccU',
#  '_r2ooFgBdoc',
#  'pI5CKxyrbiI',
#  'Y78PadVft7I',
#  'DyvsMKsEsyE',
#  '5N5-Q1tf51o',
#  '1FMTmUBerHU',
#  'yuV2OxGJAEk',
#  'wtIMY2d5XMg',
#  'Jdwvd5QKNjI',
#  'GT5UDa0I1Lc',
#  '7oLczJD6zZI',
#  'T9ihLx5Tob4',
#  'FkoYpVXOP_A',
#  'yP7ukh9B6s8',
#  'yol5vs58fZ4',
#  '1BynS5MMq9Q',
#  'gHaol8yO0No',
#  'Iiugb9cV-CM',
#  'Aacv1YHSZls',
#  'RmubloSnHL0',
#  'L9ZbjzkuvBE',
#  '-0XTXIFztEg',
#  'rRgbOj0l7GA',
#  'PB4RvQsoJac',
#  'qU7ixXwcv9w',
#  'LcL8GqY4srw',
#  'wg-Mt7l2Ky4',
#  'rPfJU_BqaAk',
#  'JMk6atNyKDw',
#  'kovs9DIRF4M',
#  'S4DqxU55lk0',
#  '5bBWSfSidB8',
#  'By7d1zGEu6M',
#  'Kbqdqd7cIbY',
#  'okli_BD_s8Y',
#  '2AyxS4dvmV0',
#  'WDk5O-yaoCQ',
#  '3CeMtuV3StE',
#  'n1sV50hKv18',
#  'wOioMoJ_sX8',
#  'vflleO_p6eM',
#  'AAHR7eBKLU8',
#  'vMv6enknWJs',
#  'Kg7fioDq8CE',
#  'n6jSV0fSTd4',
#  '7LHPEWEIpI0',
#  'D-XXOlN1MeE',
#  'tkNrXrNRGLY',
#  'ya7nogGFzQc',
#  'AK0pKG3868Q',
#  'bPgXLxl5nLs',
#  'w_1fb0ylmGU',
#  'SSNbf2fyiEk',
#  'nd64lS7UpKo',
#  'KNaxnId5Czs',
#  '5UTBU4oiYg4',
#  'agc5OuOic40',
#  'nSuQfoDXKHA',
#  'qSD1Fdy09Vc',
#  'yJ4wOnrwMRE',
#  'eoynde3KxFM',
#  'I7LpgP2iyUQ',
#  'T7gy7jFT9rc',
#  '0hm3tdAjTOM',
#  'xrvMocqtuPA',
#  'IBDreF4W9oo',
#  'D8IJOwdNSkc',
#  'ER_kXCDnPrc',
#  'QMU26H-ZN2E',
#  'Pv_0UpaxVHU',
#  '6BffPT96HPg',
#  'ESp6cjpuvvk',
#  'hLvMHT0OirQ',
#  'O9qcVRHIdLQ',
#  'WM9WcEHxJmg',
#  'UK-c1NkdLA0',
#  'rVp30tTx1qk',
#  'cThj3XGntHg',
#  'CQL8D9q_-1w',
#  'LCRYzDyd-Tw',
#  'd0HEVofke6U',
#  'RzRAQrytGo8',
#  'yUsbiWbN_EQ',
#  'xWXxkFzgnFM',
#  'FmKjwh34Rn8',
#  'vbaIZ3xMj9U',
#  'tKRWuVOEB2w',
#  'k0WnY0Hqe5c',
#  'cAZ-fOd1RpA',
#  'gmF4k6P2va8',
#  '6ZSF60zVFow',
#  'A9bA5HpOk30',
#  'G3gnMSyX-XM',
#  'V9egJMknKtM',
#  '82gwumVIXFo',
#  'r1Iygf-rRdE',
#  'p2LOVWwCIl0',
#  '1ZWdUvrxpb8',
#  'E270S3eNqSg',
#  'mPuyU4kdlVE',
#  '_ue0muXQk_8',
#  'o9hT7v0OLJc',
#  'pUlwhe-kmog',
#  'qNXhhrJIv-w',
#  '14j5fq4Sodg',
#  'ewVZadu0gzw',
#  '_dBqj7KJPK8',
#  'JKbh5PpRRoI',
#  'b6yi7R1LOzE',
#  'gG-M13RS0uI',
#  'TA0Ubns2tsE',
#  'Yr6HOyWUCgE',
#  'nSPoZ-Fom7s',
#  'qCnQgZzoIMM',
#  'j76v-9YjwNk',
#  'G-Kj8Re6spA',
#  'obtd9TYS1Zc',
#  '2GFpBctSO3g',
#  'DU6-Sk7s6N0',
#  'FMCX25WjU9o',
#  't3Q0NYWcQiQ',
#  'I6IY2TqnPDA',
#  'em2RlWPYlVE',
#  'ZluNj0-NpNI',
#  'ke1pkMV44iU',
#  'T3Px88x_PsA',
#  'FM2RN8rHCTE',
#  'doshF5Alr-k',
#  'fd4_IEWzYeo',
#  'fcvYiYfCGVY',
#  'ZEUAzZSzFoI',
#  '3wvdq_j5S1c',
#  '5JQ-liomDgg',
#  '34fE23aib1o',
#  'jSpihGu69v0',
#  'ICmMVfKjEuo',
#  'bd3UGjPwl0w',
#  '00kXjx9k3Os',
#  'MpzLX574boM',
#  'p6c7QA9ofvI',
#  'Nx3KcrYDJas',
#  'jBwoOvYLNKc',
#  'jOTH5gf_Bg4',
#  'lucF8YVidu0',
#  'U3OiL1quX0Y',
#  '9gcVG7E37xg',
#  '1VKDvaZwJ9E',
#  '3Ezn4tb1Fe0',
#  'bRVJKxfp_0s',
#  'lduIC6nPsKo',
#  'SwGs3LCipoU',
#  'Ry6Zobb-kaw',
#  'FikaE1aa0FQ',
#  'sWh97AP1rB0',
#  'j_xgoMp1vQc',
#  'BM4_IvSjRYw',
#  'T8mFqCsy-g8',
#  'PWgGkWwwHiE',
#  'V_b6i1hFsBg',
#  '54kcLG8oRgc',
#  '0t-rE5wUP-E',
#  'vPu1sfuYFzw',
#  'xLlIgokKiLc',
#  '-QQnzDVcTCo',
#  '9P1HtbpGSCk',
#  '659O4HME7Mg',
#  '4Wf4iw68ejo',
#  'XLxCmfOIxu0',
#  'vDdB5UyVVc4',
#  'zIwOLcaM1LA',
#  'oaZOcr6Egsg',
#  'XpGA-O6a4g0',
#  'aTyLBHpaGgk',
#  'nzhF3abDZdM',
#  '5P9UatHGvQc',
#  'jbDUti1nRAo',
#  'wR76VDYW6DY',
#  '146AypcFvAU',
#  'kzATZekmyTc',
#  'yXUoynKLp48',
#  'NCJABCNR0jk',
#  'Udx6RwVySUo',
#  'YV-1VCvVOu8',
#  'dYgqZ0FdzXI',
#  'Y-2O6ynsUfY',
#  's0V_o2CqOw4',
#  '_FQ1ZEWIn2s',
#  'tlsjqZP8_4M',
#  'CxWYdieVrT8',
#  'qCVzfqkoJCQ',
#  '22S5P_d55dM',
#  'bLQqkeVT7os',
#  'vHTFQadDbwY',
#  'lb0moT4agbI',
#  'Xwjg8meOglI',
#  'kKpoAhugjUc',
#  'qbFVSzG8qc8',
#  'Wyi2-d-2rg4',
#  'Jwz08YT8hbw',
#  'lMdw9lK5RK4',
#  'oM-EmNdhwI4',
#  'hCOmfUjscC8',
#  'sLgKXX0FrJo',
#  'mZCkcPNSixE',
#  'S2wjg5SPMUA',
#  '1OSvFy2vZhY',
#  'bPtorCF-Xko',
#  'mmrhPWe4Q8c',
#  'jsrtxnFpGaw',
#  'QJe8YBs8Afg',
#  'cuIz5Zmkl7A',
#  'Mtru6s0Bkjs',
#  'gqhE3Pj0Wjg',
#  'OVdQsiwabOw',
#  'w3oeswU1mxA',
#  'sBWtPEinWGA',
#  'TpXNX1xkwZ8',
#  'fefyV8KaFmI',
#  'FiU3SHEaFwk',
#  'qQAozc1MkdU',
#  'LN1VD_oppEQ',
#  'AdHwBKKQHZ4',
#  'aYF90AKjVfY',
#  'ZYhKsX9Alic',
#  'UWLVCPPDHTU',
#  'xJnp6LREfVk',
#  'eMjju1nQ1F8',
#  'p0z-PVjH5pc',
#  '2CBnRDJ--aM',
#  'pbCrDBQFU_A',
#  '1ZzeYPD8jZw',
#  'gsaPh7-YA9Q',
#  'jEzZD_-ABBA',
#  'kuswGIH-Xj8',
#  '0nMbsfoMAls',
#  'zomR1RVMqZY',
#  'EoqzOEZIzhg',
#  'ZcWZUSuD_jM',
#  'iM4NRM2diPc',
#  'G8KXFWftCg0',
#  'HFIjWR6bggU',
#  'iy6Z8NqzB_Q',
#  '5kd9b1tXB6E',
#  'u-pdltyzfIU',
#  'Xtxc2FbyNpA',
#  'UyNVOqOKMiQ',
#  'VrJYD3vkPMo',
#  '9CrK_sZyW8E',
#  'qMoDVC38BDk',
#  'tIWYBPOEk98',
#  'wTrPoeF-il0',
#  'YUjlBuI8xsU',
#  'ESejQpjEndk',
#  '9sr6aeZ9Xzc',
#  'NONvd8OU0S4',
#  'fz5TJjU8mek',
#  'lKvV_0xZWCg',
#  'WXHU3oyTibE',
#  'LGkIU7w2Sgg',
#  'YAmNScFKsKA',
#  'pQfA_gRSvFk',
#  'thOHGALZ7WU',
#  'pvjOOApb6nk',
#  'mFLIOoYOhx0',
#  'dN7Gc2-BmXM',
#  'TYxwyaOlj_w',
#  '0npsaFdrrFw',
#  'PNuRpf3p_vA',
#  'AkPHO2MT-sA',
#  'mEEBPmUS34U',
#  'h1_HiTbhT0Y',
#  'w4GsVAts1RY',
#  '7XUFVQh6XAQ',
#  'vKzXklv1qUA',
#  'JMLTlMAejX4',
#  'igZu0sZBL-4',
#  '4i3W6g_u1Nw',
#  'dE0OTdEIXx4',
#  '23w8PSHwep0',
#  'XyqV-kE08Yo',
#  'pOIQFxwp9hk',
#  's2nre7qbhYY',
#  '3P8cDjHsOCA',
#  '2eWIr6bbons',
#  'Kfrn5wDsQLc',
#  'SdOWxoH3HLg',
#  'VYSIT2leZ1g',
#  'OkIDr8QSrLg',
#  'dPgAXFcFHCM',
#  'se72XMlG1Ro',
#  'KQ_ty4A6Nsc',
#  'syddCEdvAhI',
#  'jRuSicPIeUY',
#  'z02Zg7zFpoc',
#  'GpmBvNF0Wyw',
#  '9EwvLpkuLSg',
#  '24riuhr3Hmo',
#  'IjZvgAmPA_o',
#  'RvfUrzMRlJ8',
#  'ay1kKni4Rkk',
#  'DT6KLSObdyk',
#  'JiAfuBkvSb4',
#  'WoUd9RoXrWk',
#  '4vxkjfjKyE0',
#  'nHehhz_a270',
#  'JfIvPDPUFo4',
#  'p7OCG_osB0E',
#  '9gm3w-Oo_us',
#  'GqIMNp7POJw',
#  'gF-peiFjG0o',
#  'RDQyAcvmbpM',
#  'NQa9B25XhSs',
#  'G0flJz7Zbvc',
#  '06ecEUSGSq4',
#  'qTuzLjENKGs',
#  'GsBXAunkPWg',
#  'Pjm3tO0eW_0',
#  'PPwcRKB3F4c',
#  'jKohh9Y7AtE',
#  'jGY4bHRWO5I',
#  'mfjFF7bYWTg',
#  'iqQR6szLeRo',
#  '5beyFcuTw20',
#  'gt8x6uODvEQ',
#  'YBy5qIsrOyk',
#  'vTCUUWOSBio',
#  'YxT60qghtvs',
#  'RH_es0awU_A',
#  'tewE75bsek4',
#  'LAzwTlj83EI',
#  'sGuiC4N76Jw',
#  'Y3jUmj2ApLw',
#  '1aucQqkt-PM',
#  'ztpG43kuMIk',
#  'nuoP52d0kqI',
#  'd_Ak1pn-n4k',
#  'UrhRCipL2aI',
#  '3brUeTkeZDI',
#  '9Z0rMXSghs4',
#  'Du4Hkhj92NU',
#  'r9LX34wIeio',
#  'pLIRxD4AK3A',
#  'lvuN_dqyk88',
#  'iL0yKGwB6ws',
#  'BqJEB1h0pqU',
#  'Ja4aVMNN240',
#  'Cfe9-lr0W88',
#  'Zb5C5EuzDQ0',
#  'yXUAqmWrEQA',
#  'D5rtqnTsh14',
#  '6tw9sJEy56M',
#  'F4eDnEQasyw',
#  'Gh7tHs1Stno',
#  'rNsjfLA8XSg',
#  '3_amlQ8RSyc',
#  'VF4D8H9GGRI',
#  '0rroukJh6oQ',
#  'd1nw3QdLv8w',
#  'U-7B_cItfH8',
#  '6mcwL_uHKCM',
#  '4Y9chGxAqmc',
#  'bXpuqDOYHGk',
#  'lDpnnTPokdA',
#  'uyOI-hUU00A',
#  'nyE6shIRzxM',
#  'yG3ibQBMMDY',
#  'gDWw4RtiKeU',
#  '_AjlQ64f-64',
#  '6dL_8cQ4Waw',
#  'axppjojlUnw',
#  'PGut1QwqNOo',
#  '83tQh41vhYk',
#  'AAsX-tzs09A',
#  'jraiAOQ83i8',
#  'GyjmWugVM60',
#  'fA_lqkc89dY',
#  'cSd8AOC7Hik',
#  'bytfIdoUhD8',
#  'eOXhdIMAWns',
#  'vyuxRJil-Rs',
#  'U0WSkAP_Ngs',
#  'G-_WPCkSyAg',
#  'XKgfszmI1bk',
#  'lGiM2ow3Kkc',
#  'FPAaDJaFAQw',
#  't6jZ8CpM_c0',
#  '4KDP7_ErC88',
#  '1eOQNpd24NQ',
#  'OLjLB0sUvs8',
#  'A5o229618H4',
#  'ikdmNo7d6nM',
#  'g5Sq4_6Jhys',
#  'yDZuJD9vXEc',
#  'mhoiwfShSnE',
#  'SX_IL7LqSxM',
#  '1I4FgHlE1lo',
#  'i3jCNghB2EE',
#  'DrngILrEJpo',
#  'GiOQmvfbK44',
#  'F8lxOmPArCg',
#  'ZL3hMP9BdmQ',
#  '0j9lrE_g4Gw',
#  'qzTqv6uLYTE',
#  'ay2EgGdJ7GY',
#  'oISGcNLje2Q',
#  'felbIYW5v18',
#  'wd0bHdheXUc',
#  'P4Ld3eYDwu4',
#  'ZWzJzOXuAcE',
#  'AQj_Z1FzAfY',
#  'aetqo2nkQcA',
#  '4W_NuaHVFbo',
#  'EpKJYnaNyKw',
#  'eCrv43wQ53A',
#  'S51bd-dFTfs',
#  'tSQ7WuAcAbU',
#  '6irLmUBAG_A',
#  'e1cbhZ5vDGc',
#  'XudEOQYfemo',
#  'JsShoi993cY',
#  'LVjSP2A3vhQ',
#  'DD6ibaRKbRk',
#  'KV1hImimZUo',
#  'u_l9eMS0q04',
#  'Zw_0PkG7_jg',
#  'dGYVyU1ENnE',
#  'WHqd12n2n7M',
#  'DIjckHKXumQ',
#  'eRXAKBrJ95g',
#  'wi_vD0Yvc0g',
#  'htrhLWHZQ4I',
#  'NtY8YPP4-dA',
#  'j9NZ6SlJfp0',
#  'vBm6ors_OjA',
#  'PtgNCvCjds0',
#  'BuFMcCqw7lw',
#  'QMrqzvOGE2E',
#  '9mpA1780GZU',
#  'MrtbtKwsBZo',
#  '1A0cyiKRcEo',
#  '9gV_H1ywhE8',
#  'cESmjhcI-yo',
#  'C2e7sYZUPB4',
#  'V8mJCkspalc',
#  'z6wUfTWdr84',
#  'Z45ToeWHCJM',
#  'zioCWRVPrJk',
#  'MuwQdUoNKzg',
#  'NdJ87XOcRBM',
#  'Ngjv79v6wQ0',
#  'sxs7ee1WY0E',
#  'Mj4xJAVs2VQ',
#  'p_kqcGW1jkY',
#  'uDfFkuvhnxs',
#  'anwo_i0wgNo',
#  'r9wP__PYgjg',
#  'gfRzLg0cpro',
#  'hbVIIukhtso',
#  'FTqZWeyt_8Y',
#  'Tv8j24zuECk',
#  'YaN0b4_vD_U',
#  'WOo8eOSgjHQ',
#  'Zb39czwhg7Q',
#  'sK9SjEjlz6U',
#  '62ueuQkPX5Q',
#  '-VgeUqpPTh4',
#  'GQCJbRbA9Ms',
#  'lBmMfNz2uSc',
#  'yGaIfZSakkI',
#  'jDvOauhkEOM',
#  'DlNVHWo_nq8',
#  'Q-hyZDW8S0E',
#  'BpEw1PNdvkg',
#  '_lzCxWQRi_0',
#  '0MKJ7JbVnFc',
#  'godFLmGf4uo',
#  'Yn_4OZ-P2cM',
#  'Ue3Tn0ZzfdY',
#  'u8UoldEIlnQ',
#  'Dsgg5i-tvqE',
#  'fUq1iHiDniY',
#  'cCBFY1yShUA',
#  'V95tULgGpLo',
#  'uOGFWF3kLhg',
#  'yPp22irc5Q0',
#  'm0QF32y8eVs',
#  'pd39vcWKsKE',
#  'syqw5UJrfoc',
#  'a5Wh_LDXtLc',
#  'DSxQUlfkISk',
#  'h5ekwDyjmW4',
#  'A8--lD6p77s',
#  'bDShL6TG-Tg',
#  '7yA7BGos2KQ',
#  'MEKoxzVhCps',
#  'X6pNLEOs-10',
#  'wth5ecLOey0',
#  '3lmsPScLHb0',
#  'Lh_6HmkCoZ0',
#  'duwlMwfEKQA',
#  '6XI6nGGiSBw',
#  '76tKpVbjhu8',
#  'YU3qstG74nw',
#  'OjUmklmqjIs',
#  'f4ZKNLmMpL4',
#  'agKRMEjqb5M',
#  '7C3rPbXmm44',
#  'UA0AIkjI85c',
#  'wKkKFkeqFEU',
#  'CgCG7TYld7k',
#  'g21uHNIIewM',
#  '_Zwqn7FV6ms',
#  'arkGcbMkWJM',
#  '4XmQi80nFes',
#  'uAlxod75FIM',
#  '8tcWrcfS8uY',
#  'jSB4Llaf2xI',
#  '2XISVihRbPY',
#  'Kz3j_Fz7X2w',
#  'b7Kq9uHhT_k',
#  'O5_j0cb3TQU',
#  'mhGPSSnnTpI',
#  'NfHRiQWl_48',
#  'HkSu74fIGuU',
#  'v_YVhMANHsA',
#  'acaGxUr4auE',
#  'm1L7fO2WvUE',
#  'z6bqj2yecGY',
#  'd9DWcOv0l9g',
#  'SnfnRbwz15U',
#  'GfDwZVAe_i4',
#  'QbPpSkpoU6I',
#  'BAWB_4XtyeQ',
#  'HbsfC11HbLY',
#  'SFcluy7n_0M',
#  'fEjevUGH4BU',
#  'jQ4YD7Ip6T4',
#  'HCwpWuv4JJY',
#  'Bq_Hkj-G-4c',
#  'XoK1a4bYgVw',
#  'WIwiqZCraQ4',
#  '7dGVDgdikYY',
#  'eUpu7GOeceA',
#  'n-Mb2HiFVKc',
#  'EifOGwAW5ZM',
#  'l9eyot_IXLY',
#  'HRBNeERE5PU',
#  'oQc7DC3srNM',
#  'sxjcWUDTYIg',
#  'LW20Rk7LGbk',
#  '-0mT8N19dLY',
#  'WwxNReczwYg',
#  'kG5RQHhYEto',
#  'WcGd8VkRc48',
#  'kFz-CY2Wv0o',
#  'IuYo009yc8w',
#  'EZlt1BaYSRQ',
#  'UdokxkOZbTk',
#  'MAWNtg6HCJQ',
#  'yjVhldDwiNE',
#  '_Dq8QnQtx5Y',
#  'FDzF2nHUexQ',
#  '9FT-X0Qwsio',
#  'aY4rHuwyiic',
#  '9PrJjdPiTaQ',
#  '6VVVWqOGGig',
#  'AUncwRXpQIY',
#  'iEBaSjYaOWs',
#  'qH4pJISKeoI',
#  '3qLJPLN33DE',
#  'oRL-pttfNSc',
#  'M4kk3Ac0WSM',
#  '01Dc5mtm1wQ',
#  'HmwEGkBKb2s',
#  'oQ60Grn4RYQ',
#  'Jz-zJ7lA4io',
#  'RYFJOUajLZs',
#  'sYar5SiY5BY',
#  'qjKZYQih288',
#  'UaxqJUXqvro',
#  '2cSVIWDUSn4',
#  'sVwD3xDoXbg',
#  'LnOemRSax4A',
#  '7Ib8k2rL13M',
#  'wmmqdXWEb1E',
#  'XmNmiBfk6M4',
#  'Tp8UPgmhyTs',
#  '635N7rU5aPo',
#  '5ugAK6hGljI',
#  'YTwoYELWMqw',
#  'RTvoOGo7_U8',
#  'eu2VJ9dtwiY',
#  'fUmoEp99i74',
#  'wyz5w9pSv40',
#  'oE8fQeWTFEQ',
#  'FvftrM5I8Ug',
#  'TU-jZTpCig4',
#  'Ffl1oWjSUF4',
#  'SaVxJrTRkrI',
#  'hqk30IVeYak',
#  'J3PH1EOPKhU',
#  'XEGabB1OIcA',
#  'JX99WVMlqdY',
#  '0YoNrTQCrHg',
#  'JUVxy8drQ_U',
#  'gBdAEh3xlcM',
#  'USYAmObWoPw',
#  'dXvPCzFBgx8',
#  'XnNWAOQK33M',
#  '_Aw_d30gTbU',
#  'f9Tr9f8TpIo',
#  'lSANb08p7hk',
#  'GA_l6meFsSw',
#  'd-cVl03dxUo',
#  'yLmyP01XhSg',
#  'kiFJ-9BEUpY',
#  'jbvjEoK4bJc',
#  'IGBRy-gMfu0',
#  'DVjMexJPVXw',
#  'HVvp88xfc7Q',
#  'iCvLZ0dzldc',
#  'gVRPTpzZymk',
#  'P1R2KE0iURE',
#  'f-Tz8YmpvA0',
#  'hyd12eV1sNc',
#  'nJTj9ovPW3o',
#  'UG1pPq8gl_c',
#  'KXvJPKpkRmI',
#  'zZaRSX42oLk',
#  'Y0d6VIrYdrQ',
#  'ZPPVjxdqYUo',
#  '4VRAhcb9hPw',
#  'w7T0sA3pOtI',
#  'ucYbmS4wk2E',
#  '_vBRBEL9GXk',
#  'Is0I5YAHFIY',
#  'ooQ7bfaB4VE',
#  'strnkHcsUWw',
#  'KloXHTYkG8Q',
#  'Q1uiqE4Dcxc',
#  'Uzpwpeg2IqQ',
#  'Tyw0xgkD06w',
#  'dHn69p0P-MM',
#  'v1PrMXgxMH8',
#  'EMACaNYCih0',
#  'UzvBjwfWC84',
#  '_KElc3T6p8k',
#  'GqnVCya62MU',
#  'twhuNzZA6nA',
#  'ogTRmesr3pw',
#  'OHeyYlVJ7js',
#  '_LDnq4Eshfw',
#  '5QoJhPXVfeE',
#  'wV_au2QT1NY',
#  'Lr8wnYWBqJE',
#  'H9dAAzu7dBY',
#  'nWZ3zg9Qylk',
#  '6GQj1la9dz0',
#  'TPWPZhg-iks',
#  'Agqx8gQVnJQ',
#  '4CEZoldd3rc',
#  'lhJi60lu8kw',
#  '7zvqd7NnJQo',
#  'wVUD9i_LYRw',
#  'RNXVnC-a--Y',
#  'wHwuZaEng88',
#  'C-MTgRUH3Pw',
#  '2iReOlF-l8c',
#  'JT2F2NQ19o0',
#  '4aDyN5cOFBw',
#  'j50ZYG0soKA',
#  'WMg9Khc0AM0',
#  'itlSR3hm5AM',
#  'PxAM1iMubEI',
#  'TUEhRlKxrOQ',
#  'yO__Aev3TeE',
#  'hZ9ES9qrFqo',
#  'bWMnVq8cN54',
#  '2uM23ql3v1U',
#  'rZp6EBXzZVs',
#  'egBOTPZdOSs',
#  'sFzbjrPUKig',
#  'J4XhvTNafNM',
#  'PASgarLoQsU',
#  ...]

# %% [markdown]
# ## Function to get video details

# %%
def get_video_details(youtube, video_ids):
     
    all_video_stats = []
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part='snippet,statistics',
            id=','.join(video_ids[i:i+50]))
        response = request.execute()
            
        for video in response['items']:
            video_stats = dict(Title = video['snippet']['title'],
                    Published_date = video['snippet']['publishedAt'],
                    Views = video['statistics']['viewCount'],
                    Likes = video['statistics']['likeCount'],
                    Comments = video['statistics']['commentCount'],)
            all_video_stats.append(video_stats)
                
    return all_video_stats

# %%
video_details = get_video_details(youtube, video_ids)

# %%
video_data = pd.DataFrame(video_details)

# %%
video_data['Published_date'] = pd.to_datetime(video_data['Published_date']).dt.date
video_data['Views'] = pd.to_numeric(video_data['Views'])
video_data['Likes'] = pd.to_numeric(video_data['Likes'])
video_data['Comments'] = pd.to_numeric(video_data['Comments'])
video_data
# Out:
#                                            Title Published_date   Views  \
# 0                  Why I'm Making an Emo Neopets     2021-12-21   47774
# 1               Why You Should Quit Your Project     2021-12-14   79221
# 2                        Coding The Next Pokemon     2021-12-10   99146
# 3              Coding Interview with Dan Abramov     2021-12-02  312655
# 4                           I Got Roasted By Vox     2021-11-17  161110
# ...                                          ...            ...     ...
# 1091            Stack Calculator - Promo Updated     2015-03-24     354
# 1092                           LoL Scout - Promo     2015-03-23    1695
# 1093  Behind The Scenes Look at Stack Calculator     2015-03-17    2788
# 1094                How to use an RPN calculator     2015-03-17   11929
# 1095                    Stack Calculator - Promo     2015-03-13    6417
#
#       Likes  Comments
# 0      3461       238
# 1      3967       200
# 2      6736       399
# 3     10852       991
# 4      7634       336
# ...     ...       ...
# 1091      6         0
# 1092     14         7
# 1093     26         5
# 1094    110        35
# 1095     97        22
#
# [1096 rows x 5 columns]

# %%
top10_videos = video_data.sort_values(by='Views', ascending=False).head(10)

# %%
top10_videos
# Out:
#                                                  Title Published_date  \
# 74                        Coding Interviews are Broken     2020-04-13
# 38   Beginner React.js Coding Interview (ft. Clémen...     2020-11-20
# 54         Fullstack React GraphQL TypeScript Tutorial     2020-08-20
# 64                          Why I don't work for FAANG     2020-06-19
# 104                   How to Configure Vim like VSCode     2019-11-11
# 43               Programmer Explains Programming Memes     2020-10-09
# 86                    Why React Native is NOT garbage.     2020-02-06
# 125                          React Typescript Tutorial     2019-09-05
# 98               How to Become a Web Developer in 2020     2019-12-12
# 63               Software Engineering "Best Practices"     2020-06-26
#
#        Views  Likes  Comments
# 74   1466192  69838      3941
# 38   1119115  27294      1390
# 54    839737  29076      2012
# 64    594734  24727      1349
# 104   558458  10155       620
# 43    438742  20284      1016
# 86    422893  13022      1102
# 125   403722  10530       353
# 98    396354  15721       616
# 63    391308  15768       784

# %%
ax1 = sns.barplot(x='Views',y='Title',data=top10_videos)

# %%
video_data['Month'] = pd.to_datetime(video_data['Published_date']).dt.strftime('%b')

# %%
videos_per_month = video_data.groupby('Month', as_index=False).size()
videos_per_month
# Out:
#    Month  size
# 0    Apr   109
# 1    Aug    85
# 2    Dec   125
# 3    Feb    74
# 4    Jan    78
# 5    Jul    89
# 6    Jun    98
# 7    Mar    99
# 8    May    99
# 9    Nov    78
# 10   Oct    81
# 11   Sep    81

# %%
sort_order = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
videos_per_month.index = pd.CategoricalIndex(videos_per_month['Month'],categories=sort_order,ordered=True)
videos_per_month = videos_per_month.sort_index()

# %%
ax2 = sns.barplot(x='Month',y='size',data=videos_per_month)

# %%
video_data.to_csv('Video_Details(Ben Awad).csv')
